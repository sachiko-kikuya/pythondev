# %%
import matplotlib.pyplot as plt
import numpy as np

# データの定義
x = np.array([62, 95, 83, 100, 72, 71, 55, 85, 67, 75])   # english
y = np.array([62, 80, 85, 95, 58, 76, 52, 84, 67, 71])    # math

# np.polyfit()を使用して最小二乗法による1次近似
coefficients = np.polyfit(x, y, 1)  # 1次多項式で近似
a, b = coefficients  # 傾き(a)と切片(b)

# グラフの作成
plt.figure()

# 散布図をプロット（青色）
plt.scatter(x, y, color='blue', label='score')

# 近似直線をプロット（赤色）
plt.plot(x_line, y_line, color='red', label='lsm')

# 軸ラベルの設定
plt.xlabel('english')
plt.ylabel('math')

# 凡例を左上に表示
plt.legend(loc='upper left')

# グラフを表示
plt.tight_layout()
plt.show()
